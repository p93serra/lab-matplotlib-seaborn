# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
fig1, ax1 = plt.subplots()

# we add a title to the figure or the ax
ax1.set_title('Method 1', fontsize=20)

# we plot the different lines
ax1.plot(x, y, c='blue', label='y = 2x', linewidth=2, ls='--')
ax1.plot(x, z, c='red', label='z = x^2', linewidth=2, ls='solid')

# we add the legend
ax1.legend()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig2, ax2 = plt.subplots(1, 2, figsize=(15, 5))

# we add a title to the figure or the ax
fig2.suptitle('Method 2', fontsize=20)

# we plot the different lines
ax2[0].plot(x, y, c='blue', label='y = 2x', linewidth=2, ls='--')
ax2[1].plot(x, z, c='red', label='z = x^2', linewidth=2, ls='solid')

# we add the legend
ax2[0].legend()
ax2[1].legend()

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
y1 = x**2
y2 = math.exp(1)**x

fig3, ax3 = plt.subplots(1, 2, figsize=(15, 5))

# we add a title to the figure or the ax
fig3.suptitle('Scales', fontsize=20)

# we plot the different lines
ax3[0].plot(x, y1, c='blue', label='y = x^2', linewidth=2, ls='--')
ax3[1].plot(x, y2, c='red', label='y = e^x', linewidth=2, ls='solid')

# change the scale
ax3[1].set_yscale('log')

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
fig3, ax3 = plt.subplots(1, 2, figsize=(15, 5))

# we add a title to the figure or the ax
fig3.suptitle('Scales', fontsize=20)

# we plot the different lines
ax3[0].plot(x, y1, c='blue', label='y = x^2', linewidth=2, ls='--')
ax3[1].plot(x, y2, c='red', label='y = e^x', linewidth=2, ls='solid')

# change the scale
ax3[1].set_yscale('log')

# we add the legend
ax3[0].legend()
ax3[1].legend()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit2 = pd.read_csv("../data/Fitbit2.csv")

# %%
fitbit2.head()
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# 1                     316                     61                   60
# 2                     226                     14                   77
# 3                     190                     23                    4
# 4                     171                      0                    0
#
#    Activity Calories  ...  Distance_miles      Days  Days_encoded  \
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
steps_by_month = fitbit2.groupby('Months_encoded')['Steps'].mean()

fig4, ax4 = plt.subplots(1, 2, figsize=(12,4))

# set title
ax4[0].set_title('Avg. Steps by month', fontweight = 'bold')

# plot the bar chart
ax4[0].bar(x=steps_by_month.index, height=steps_by_month.values)

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
steps_by_day = fitbit2.groupby('Work_or_Weekend')['Steps'].mean()

# set title
ax4[1].set_title('Avg. Steps by Workday or Weekend', fontweight = 'bold')

# plot the bar chart
ax4[1].bar(x=('Work','Weekend'), height=steps_by_day.values, color=('blue','green'))

plt.savefig('../figures/steps_analysis.png', transparent=True)

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
fig5, ax5 = plt.subplots(1, 3, figsize=(18,4))

x_categ = ["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
c_categ = ['orange', 'red', 'blue']

for i in range(len(ax5)):
    ax5[i].scatter(fitbit2[x_categ[i]], fitbit2["Steps"], c=c_categ[i])
    ax5[i].set_title(x_categ[i], fontweight = 'bold')
    ax5[i].set(xlabel='Minutes', ylabel='Steps')

plt.savefig('../figures/steps_by_activity.png', transparent=False)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv("../data/titanic.csv")

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Gender       1309 non-null   object
#  5   Age          1309 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1309 non-null   float64
#  10  Cabin        1309 non-null   object
#  11  Embarked     1309 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes(include=['int64','float64']).columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes(exclude=['int64','float64']).columns
# Out:
# Index(['Name', 'Gender', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
fig6, ax6 = plt.subplots(figsize=(12, 6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
plt.style.use('classic')
fig6, ax6 = plt.subplots(figsize=(12, 6))
ax6.hist(titanic["Age"])
fig6.suptitle('Age Distribution', fontsize=20)

plt.savefig('../figures/titanic_age_distribution.png', transparent=False)

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
plt.style.use('classic')
fig7, ax7 = plt.subplots(1, 4, figsize=(16, 6))

bins_list = [10, 20, 50, 80]

for i in range(len(bins_list)):
    ax7[i].hist(titanic["Age"], bins=bins_list[i])
    ax7[i].set_title("BINS " + str(bins_list[i]), fontweight = 'bold')

fig7.suptitle('Age Distribution by nº of bins', fontsize=20, y=1.03)
plt.savefig('../figures/titanic_age_distribution_by_bins.png', transparent=False)

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
The number of bins affects the detail in the analysis of the results. It also don't show the shape with a lot of bins.
"""

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here
fig8 = sns.histplot(data=titanic, x="Age")
fig8.set_title('Age distribution', size=20, fontweight='bold', y=1.01)
plt.savefig('../figures/titanic_age_distribution_seaborn.png', transparent=False)

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
gender = titanic.Gender.value_counts()

# %%
# Method 1 - matplotlib
# your code here
fig9, ax9 = plt.subplots()

# set title
ax9.set_title('Titanic Gender Rate', fontweight = 'bold')
ax9.set(xlabel='Gender', ylabel='Nº people')

# plot the bar chart
ax9.bar(x=gender.index, height=gender.values, color = ('blue', 'pink'))

plt.savefig('../figures/titanic_gender_distribution_matplotlib.png', transparent=False)

# %%
# Method 2 - seaborn
# your code here
gender_df = titanic.groupby('Gender')['PassengerId'].count().reset_index()

fig10, ax10 = plt.subplots(figsize=(8, 5))

sns.barplot(data=gender_df, x='Gender', y='PassengerId', ax=ax10)

ax10.set_title('Titanic Gender Rate', fontweight = 'bold')
ax10.set(xlabel='Gender', ylabel='Nº people')

plt.savefig('../figures/titanic_gender_distribution_seaborn.png', transparent=False)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
p_class = titanic.Pclass.value_counts()

# %%
# your code here
fig11, ax11 = plt.subplots()

# set title
ax11.set_title('Titanic Class Rate', fontweight = 'bold')
ax11.set(xlabel='Class', ylabel='Nº people')

# plot the bar chart
ax11.bar(x=p_class.index, height=p_class.values, color = ('blue', 'cyan', 'royalblue'))

plt.savefig('../figures/titanic_class_distribution.png', transparent=False)

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here
fig12, ax12 = plt.subplots(figsize=(12, 3))

ax12.boxplot(titanic.Age, vert=False)

ax12.set_title('Titanic Age - Box Plot', fontweight = 'bold')
ax12.set(xlabel='Age', ylabel='')

plt.savefig('../figures/titanic_age_boxplot.png', transparent=False)

# %%
"""
I would choose to use the box plot in order to have the summary statistics of the feature Age.
As it shows the mean, std.dev, ...
"""

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
It shows that mainly we have young people in the boat. The average age is around 29 years old. But we have some
passengers that are much older than the rest of the passengers.
"""

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
fig13, ax13 = plt.subplots()

# set title
ax13.set_title('Fare vs. Age', fontweight = 'bold')
ax13.set(xlabel='Age', ylabel='Fare')

# plot the bar chart
ax13.scatter(x=titanic.Age, y=titanic.Fare)

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025325 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.065376 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.425965  0.060832  0.018322
# Age             0.025325 -0.065376 -0.425965  1.000000 -0.260706 -0.145488
# SibSp          -0.055224 -0.035322  0.060832 -0.260706  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.145488  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.171355  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.171355
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
# your code here

# Compute the correlation matrix
corr = titanic.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
fig14, ax14 = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
MOST CORRELATED FEATURES:
- Pclass vs. Fare  (-0.559)
- Pclass vs. Age   (-0.426)
- Parch  vs. SibSp (+0.374)
"""

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here
fig15, ax15 = plt.subplots(3, 1, figsize=(12, 12))

for i in range(3):
    ax15[i].boxplot(titanic[titanic.Pclass == i+1].Age, vert=False)
    ax15[i].set_title("CLASS " + str(i+1), fontweight = 'bold')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
fig16 = sns.FacetGrid(titanic, col="Age",  row="Gender")
fig16.map(sns.scatterplot, "total_bill", "tip")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-206-5934cc6f95af> in <module>
#       1 # your code here
# ----> 2 fig16 = sns.FacetGrid(titanic, col="Age",  row="Gender")
#       3 fig16.map(sns.scatterplot, "total_bill", "tip")
#
# /usr/local/lib/python3.9/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.9/site-packages/seaborn/axisgrid.py in __init__(self, data, row, col, hue, col_wrap, sharex, sharey, height, aspect, palette, row_order, col_order, hue_order, hue_kws, dropna, legend_out, despine, margin_titles, xlim, ylim, subplot_kws, gridspec_kws, size)
#     458         # --- Make the axes look good
#     459
# ...
